# %%
# !pip install spacy scikit-learn
# Out:
# Collecting spacy
#   Downloading spacy-3.8.14-cp312-cp312-win_amd64.whl.metadata (28 kB)
# Requirement already satisfied: scikit-learn in c:\users\cbala\anaconda3\lib\site-packages (1.5.1)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Downloading murmurhash-1.0.15-cp312-cp312-win_amd64.whl.metadata (2.3 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Downloading cymem-2.0.13-cp312-cp312-win_amd64.whl.metadata (9.9 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Downloading preshed-3.0.13-cp312-cp312-win_amd64.whl.metadata (5.4 kB)
# Collecting thinc<8.4.0,>=8.3.12 (from spacy)
#   Downloading thinc-8.3.13-cp312-cp312-win_amd64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Downloading wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.5.3 (from spacy)
#   Downloading srsly-2.5.3-cp312-cp312-win_amd64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<2.0.0,>=1.0.0 (from spacy)
#   Downloading weasel-1.0.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting confection<2.0.0,>=1.3.2 (from spacy)
#   Downloading confection-1.3.3-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\cbala\anaconda3\lib\site-packages (from spacy) (0.19.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\cbala\anaconda3\lib\site-packages (from spacy) (4.66.5)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\cbala\anaconda3\lib\site-packages (from spacy) (1.26.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\cbala\anaconda3\lib\site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in c:\users\cbala\anaconda3\lib\site-packages (from spacy) (2.8.2)
# Requirement already satisfied: jinja2 in c:\users\cbala\anaconda3\lib\site-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\cbala\anaconda3\lib\site-packages (from spacy) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\cbala\anaconda3\lib\site-packages (from spacy) (24.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\cbala\anaconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\cbala\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\cbala\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\cbala\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\cbala\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\cbala\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\cbala\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cbala\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\cbala\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cbala\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.12.14)
# Collecting blis<1.4.0,>=1.3.0 (from thinc<8.4.0,>=8.3.12->spacy)
#   Downloading blis-1.3.3-cp312-cp312-win_amd64.whl.metadata (7.7 kB)
# Requirement already satisfied: colorama in c:\users\cbala\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\cbala\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\cbala\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\cbala\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.7.1)
# Collecting cloudpathlib>=0.7.0 (from weasel<2.0.0,>=1.0.0->spacy)
#   Downloading cloudpathlib-0.24.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: smart-open>=5.2.1 in c:\users\cbala\anaconda3\lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (5.2.1)
# Requirement already satisfied: httpx>=0.24.0 in c:\users\cbala\anaconda3\lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.27.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\cbala\anaconda3\lib\site-packages (from jinja2->spacy) (2.1.3)
# Requirement already satisfied: anyio in c:\users\cbala\anaconda3\lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\cbala\anaconda3\lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\cbala\anaconda3\lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\cbala\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.14.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\cbala\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\cbala\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\cbala\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.0)
# Downloading spacy-3.8.14-cp312-cp312-win_amd64.whl (14.2 MB)
#    ---------------------------------------- 0.0/14.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.2 MB ? eta -:--:--
#     --------------------------------------- 0.3/14.2 MB ? eta -:--:--
#     --------------------------------------- 0.3/14.2 MB ? eta -:--:--
#    - -------------------------------------- 0.5/14.2 MB 764.3 kB/s eta 0:00:18
#    - -------------------------------------- 0.5/14.2 MB 764.3 kB/s eta 0:00:18
#    -- ------------------------------------- 0.8/14.2 MB 780.2 kB/s eta 0:00:18
#    --- ------------------------------------ 1.3/14.2 MB 1.0 MB/s eta 0:00:13
#    ----- ---------------------------------- 1.8/14.2 MB 1.3 MB/s eta 0:00:10
#    ------- -------------------------------- 2.6/14.2 MB 1.6 MB/s eta 0:00:08
#    --------- ------------------------------ 3.4/14.2 MB 1.9 MB/s eta 0:00:06
#    ----------- ---------------------------- 3.9/14.2 MB 2.0 MB/s eta 0:00:06
#    ----------- ---------------------------- 4.2/14.2 MB 1.9 MB/s eta 0:00:06
#    -------------- ------------------------- 5.2/14.2 MB 2.1 MB/s eta 0:00:05
#    ----------------- ---------------------- 6.3/14.2 MB 2.4 MB/s eta 0:00:04
#    --------------------- ------------------ 7.6/14.2 MB 2.7 MB/s eta 0:00:03
#    ---------------------- ----------------- 8.1/14.2 MB 2.8 MB/s eta 0:00:03
#    ------------------------- -------------- 8.9/14.2 MB 2.8 MB/s eta 0:00:02
#    ------------------------- -------------- 9.2/14.2 MB 2.7 MB/s eta 0:00:02
#    ---------------------------- ----------- 10.0/14.2 MB 2.7 MB/s eta 0:00:02
#    ------------------------------- -------- 11.3/14.2 MB 2.9 MB/s eta 0:00:02
#    ----------------------------------- ---- 12.6/14.2 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  14.2/14.2 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------- 14.2/14.2 MB 3.1 MB/s eta 0:00:00
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading confection-1.3.3-py3-none-any.whl (35 kB)
# Downloading cymem-2.0.13-cp312-cp312-win_amd64.whl (40 kB)
# Downloading murmurhash-1.0.15-cp312-cp312-win_amd64.whl (25 kB)
# Downloading preshed-3.0.13-cp312-cp312-win_amd64.whl (122 kB)
# Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.5.3-cp312-cp312-win_amd64.whl (652 kB)
#    ---------------------------------------- 0.0/652.5 kB ? eta -:--:--
#    ---------------------------------------- 652.5/652.5 kB 5.0 MB/s eta 0:00:00
# Downloading thinc-8.3.13-cp312-cp312-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------------------------ --------- 1.3/1.7 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 4.4 MB/s eta 0:00:00
# Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Downloading weasel-1.0.0-py3-none-any.whl (50 kB)
# Downloading blis-1.3.3-cp312-cp312-win_amd64.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    ------ --------------------------------- 1.0/6.2 MB 5.6 MB/s eta 0:00:01
#    ---------------- ----------------------- 2.6/6.2 MB 6.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.7/6.2 MB 6.2 MB/s eta 0:00:01
#    -------------------------------- ------- 5.0/6.2 MB 6.3 MB/s eta 0:00:01
#    -------------------------------------- - 6.0/6.2 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 5.3 MB/s eta 0:00:00
# Downloading cloudpathlib-0.24.0-py3-none-any.whl (63 kB)
# Installing collected packages: wasabi, spacy-loggers, spacy-legacy, murmurhash, cymem, confection, cloudpathlib, catalogue, blis, srsly, preshed, thinc, weasel, spacy
# Successfully installed blis-1.3.3 catalogue-2.0.10 cloudpathlib-0.24.0 confection-1.3.3 cymem-2.0.13 murmurhash-1.0.15 preshed-3.0.13 spacy-3.8.14 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.5.3 thinc-8.3.13 wasabi-1.1.3 weasel-1.0.0

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Using cached https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import pandas as pd
import spacy

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
nlp = spacy.load("en_core_web_sm")

print("spaCy model loaded successfully!")
# Out:
# spaCy model loaded successfully!

# %%
jobs = pd.read_csv(
    r"C:\Users\cbala\OneDrive\Desktop\RecruitSmart\data\jobs_cleaned.csv"
)

jobs.head()
# Out:
#    job_id                                      title            location  \
# 0       1                           Marketing Intern    US, NY, New York
# 1       2  Customer Service - Cloud Video Production      NZ, , Auckland
# 2       3    Commissioning Machinery Assistant (CMA)       US, IA, Wever
# 3       4          Account Executive - Washington DC  US, DC, Washington
# 4       5                        Bill Review Manager  US, FL, Fort Worth
#
#   department salary_range                                    company_profile  \
# 0  Marketing          NaN  We're Food52, and we've created a groundbreaki...
# 1    Success          NaN  90 Seconds, the worlds Cloud Video Production ...
# 2        NaN          NaN  Valor Services provides Workforce Solutions th...
# 3      Sales          NaN  Our passion for improving quality of life thro...
# 4        NaN          NaN  SpotSource Solutions LLC is a Global Human Cap...
#
#                                          description  \
# 0  Food52, a fast-growing, James Beard Award-winn...
# 1  Organised - Focused - Vibrant - Awesome!Do you...
# 2  Our client, located in Houston, is actively se...
# 3  THE COMPANY: ESRI – Environmental Systems Rese...
# 4  JOB TITLE: Itemization Review ManagerLOCATION:...
#
#                                         requirements  \
# 0  Experience with content management systems a m...
# 1  What we expect from you:Your key responsibilit...
# 2  Implement pre-commissioning and commissioning ...
# 3  EDUCATION: Bachelor’s or Master’s in GIS, busi...
# 4  QUALIFICATIONS:RN license in the State of Texa...
#
#                                             benefits  telecommuting  \
# 0                                                NaN              0
# 1  What you will get from usThrough being part of...              0
# 2                                                NaN              0
# 3  Our culture is anything but corporate—we have ...              0
# 4                              Full Benefits Offered              0
#
#    has_company_logo  has_questions employment_type required_experience  \
# 0                 1              0           Other          Internship
# 1                 1              0       Full-time      Not Applicable
# 2                 1              0             NaN                 NaN
# 3                 1              0       Full-time    Mid-Senior level
# 4                 1              1       Full-time    Mid-Senior level
#
#   required_education                   industry              function  \
# 0                NaN                        NaN             Marketing
# 1                NaN  Marketing and Advertising      Customer Service
# 2                NaN                        NaN                   NaN
# 3  Bachelor's Degree          Computer Software                 Sales
# 4  Bachelor's Degree     Hospital & Health Care  Health Care Provider
#
#    fraudulent                                  clean_description  \
# 0           0  food52 a fastgrowing james beard awardwinning ...
# 1           0  organised focused vibrant awesomedo you have a...
# 2           0  our client located in houston is actively seek...
# 3           0  the company esri environmental systems researc...
# 4           0  job title itemization review managerlocation f...
#
#                                   clean_requirements
# 0  experience with content management systems a m...
# 1  what we expect from youyour key responsibility...
# 2  implement precommissioning and commissioning p...
# 3  education bachelors or masters in gis business...
# 4  qualificationsrn license in the state of texas...

# %%
jobs["text"] = (
    jobs["description"].fillna("") + " " +
    jobs["requirements"].fillna("")
)

# %%
sample_text = jobs.loc[0, "text"]

doc = nlp(sample_text)

# %%
for entity in doc.ents:
    print(entity.text, "------>", entity.label_)
# Out:
# James Beard Award-winning ------> PERSON
# New York City ------> GPE
# Huffington Post ------> ORG
# Yahoo ------> ORG
# Buzzfeed ------> ORG
# PR &amp ------> ORG
# Twitter ------> PERSON
# PinterestLoves ------> ORG
# working long hours ------> TIME

# %%
tfidf = TfidfVectorizer(
    stop_words="english",
    max_features=500
)

tfidf_matrix = tfidf.fit_transform(jobs["text"])

# %%
print(tfidf_matrix.shape)
# Out:
# (17880, 500)

# %%
feature_names = tfidf.get_feature_names_out()

print(feature_names[:50])
# Out:
# ['10' '12' '30' 'ability' 'able' 'account' 'accounting' 'accounts'
#  'achieve' 'activities' 'additional' 'administration' 'administrative'
#  'advertising' 'agency' 'agile' 'amp' 'analysis' 'analytical' 'analytics'
#  'app' 'application' 'applications' 'apply' 'approach' 'appropriate'
#  'architecture' 'area' 'areas' 'aspects' 'assigned' 'assist' 'attention'
#  'attitude' 'available' 'bachelor' 'background' 'base' 'based' 'basic'
#  'basis' 'benefits' 'best' 'big' 'brand' 'build' 'building' 'business'
#  'businesses' 'calls']

# %%
cosine_sim = cosine_similarity(tfidf_matrix)

# %%
print(cosine_sim.shape)
# Out:
# (17880, 17880)
